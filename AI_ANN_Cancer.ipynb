# %% [markdown]
# #ANN model to predict Breast Cancer

# %% [markdown]
# # ->Loading the necessary librabries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #-> Loading the dataset

# %%
df = pd.read_csv("/content/breast_cancer.csv")

# %% [markdown]
# #**EDA :**

# %% [markdown]
# #->peeking at the dataset

# %%
df.head(20)
# Out:
#           id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0     842302         M  ...                  0.11890          NaN
# 1     842517         M  ...                  0.08902          NaN
# 2   84300903         M  ...                  0.08758          NaN
# 3   84348301         M  ...                  0.17300          NaN
# 4   84358402         M  ...                  0.07678          NaN
# 5     843786         M  ...                  0.12440          NaN
# 6     844359         M  ...                  0.08368          NaN
# 7   84458202         M  ...                  0.11510          NaN
# 8     844981         M  ...                  0.10720          NaN
# 9   84501001         M  ...                  0.20750          NaN
# 10    845636         M  ...                  0.08452          NaN
# 11  84610002         M  ...                  0.10480          NaN
# 12    846226         M  ...                  0.10230          NaN
# ...

# %% [markdown]
# # ->Let's see how many rows and columns we got!

# %%
df.shape
# Out:
# (569, 33)

# %% [markdown]
# #->Let's see some facts here

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# #->Let's get some statistics summary

# %%
df.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %% [markdown]
# #->check for missing values.

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# #->Deleting irrelevant columns

# %%
df.drop(axis=1, columns=['id','Unnamed: 32'], inplace=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df1 = df

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df['diagnosis'].replace({'M':1,'B':0}, inplace=True)

# %%
df.head(20)
# Out:
#     diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0           1        17.99  ...          0.4601                  0.11890
# 1           1        20.57  ...          0.2750                  0.08902
# 2           1        19.69  ...          0.3613                  0.08758
# 3           1        11.42  ...          0.6638                  0.17300
# 4           1        20.29  ...          0.2364                  0.07678
# 5           1        12.45  ...          0.3985                  0.12440
# 6           1        18.25  ...          0.3063                  0.08368
# 7           1        13.71  ...          0.3196                  0.11510
# 8           1        13.00  ...          0.4378                  0.10720
# 9           1        12.46  ...          0.4366                  0.20750
# 10          1        16.02  ...          0.2948                  0.08452
# 11          1        15.78  ...          0.3792                  0.10480
# ...

# %%
df1.diagnosis.dtypes
# Out:
# dtype('int64')

# %%
benign = df1[df1.diagnosis==0].radius_mean

# %%
malignant = df1[df1.diagnosis==1].radius_mean

# %% [markdown]
# #-> plotting histogram to get some insights

# %%
plt.xlabel('radius_mean')
plt.ylabel('Number of people')
plt.title('Malignant Versus Benign')
plt.hist([benign,malignant], color=['green','red'], label=['Benign','Malignant'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
texture_benign = df1[df1.diagnosis==0].texture_mean 
texture_mal = df1[df1.diagnosis==1].texture_mean

# %%
plt.xlabel('texture_mean')
plt.ylabel('Number of people')
plt.title('Malignant Versus Benign')
plt.hist([texture_benign,texture_mal], color=['green','red'], label=['Benign','Malignant'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
symmetry_mean_benign = df1[df1.diagnosis==0].symmetry_mean  
symmetry_mean_mal = df1[df1.diagnosis==1].symmetry_mean

# %%
plt.xlabel('symmetry_mean')
plt.ylabel('Number of people')
plt.title('Malignant Versus Benign')
plt.hist([symmetry_mean_benign,symmetry_mean_mal], color=['green','red'], label=['Benign','Malignant'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# #-> Seperating the target variable

# %%
X = df1.drop('diagnosis', axis = 'columns')
y = df1.diagnosis

# %%
X.shape
# Out:
# (569, 30)

# %%
y.shape
# Out:
# (569,)

# %% [markdown]
# #-> Scaling the Data

# %%
from sklearn.preprocessing import StandardScaler
scaled_features = StandardScaler().fit_transform(X)
x = pd.DataFrame(scaled_features, index=df1.index, columns=X.columns)

# %%
x
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0       1.097064     -2.073335  ...        2.750622                 1.937015
# 1       1.829821     -0.353632  ...       -0.243890                 0.281190
# 2       1.579888      0.456187  ...        1.152255                 0.201391
# 3      -0.768909      0.253732  ...        6.046041                 4.935010
# 4       1.750297     -1.151816  ...       -0.868353                -0.397100
# ..           ...           ...  ...             ...                      ...
# 564     2.110995      0.721473  ...       -1.360158                -0.709091
# 565     1.704854      2.085134  ...       -0.531855                -0.973978
# 566     0.702284      2.045574  ...       -1.104549                -0.318409
# 567     1.838341      2.336457  ...        1.919083                 2.219635
# 568    -1.808401      1.221792  ...       -0.048138                -0.751207
#
# [569 rows x 30 columns]

# %% [markdown]
# #-> Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,
                                                    test_size=0.3,
                                                    random_state=44)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %% [markdown]
# #->Building the ANN model

# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
model = keras.Sequential()
model.add(layers.Dense(4, activation='relu',input_shape=(30,)))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

model.fit(X_train, y_train, batch_size= 32, epochs=100)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5541 - accuracy: 0.6759
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4961 - accuracy: 0.7010
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.7337
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4193 - accuracy: 0.7588
# Epoch 5/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3917 - accuracy: 0.8543
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.8970
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3409 - accuracy: 0.9020
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3163 - accuracy: 0.9070
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2938 - accuracy: 0.9121
# Epoch 10/100
# ...

# %% [markdown]
# #->Evaluate the model

# %%
model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0923 - accuracy: 0.9766
# [0.09228148311376572, 0.9766082167625427]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# array([[0.97731566],
#        [0.9999846 ],
#        [0.0027158 ],
#        [0.9999937 ],
#        [0.40893364]], dtype=float32)

# %%
y_test[:5]
# Out:
# 43     1
# 499    1
# 102    0
# 252    1
# 542    0
# Name: diagnosis, dtype: int64

# %% [markdown]
# #->Rounding off predictions to 0 and 1

# %%
y_pred =[]
for i in yp:
  if i >= 0.49:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [1, 1, 0, 1, 0, 0, 0, 0, 1, 0]

# %%
y_test[:10]
# Out:
# 43     1
# 499    1
# 102    0
# 252    1
# 542    0
# 438    0
# 404    0
# 406    0
# 230    1
# 114    0
# Name: diagnosis, dtype: int64

# %% [markdown]
# #-> Model works good to predict Malignant or Benign
# # **train** accuracy **98%** and **test** accuracy of **97%**

# %% [markdown]
# #->Classification  report

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       108
#            1       0.97      0.97      0.97        63
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# #-> Confusion  matrix

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test, predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')

plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(69.0, 0.5, 'Truth')
